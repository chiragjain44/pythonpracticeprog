# %%
class student:
    def __init__(self):
        print("hello")
        print(id(self))

obj1=student()
# Out:
# hello
# 2527744247136

# %%
id(obj1)
# Out:
# 2527744247136

# %%
import pandas as pd

# %%
df=pd.read_csv("D://pandas//placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.sample()
# Out:
#     cgpa  resume_score  placed
# 28  7.46          7.67       1

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.loc[1:3,['cgpa']]
# Out:
#    cgpa
# 1  6.17
# 2  8.27
# 3  6.88

# %%
df.iloc[1:5,[0,1,2]]
# Out:
#    cgpa  resume_score  placed
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.dtypes
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
df.empty#is any value empty or not
# Out:
# False

# %%
df.isnull().sum()#for check missing value
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.dropna()#for remove missing row
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (100, 3)

# %%
df.size
# Out:
# 300

# %%
df.values#get a numpy array for DaytaFrame
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df.copy
# Out:
# <bound method NDFrame.copy of     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]>

# %%
p=df.sort_values(by='resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
r=df.sort_index()
r
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
#change column datatype

# %%
df['cgpa']=df['cgpa'].astype(int)

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df.drop(columns='place')

# %%
df['cgpa']=df['cgpa'].add(4)

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df.count()
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
df.sum()
# Out:
# cgpa            1047.00
# resume_score     693.05
# placed            50.00
# dtype: float64

# %%
df.count()
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
df.max()
# Out:
# cgpa            13.00
# resume_score     9.06
# placed           1.00
# dtype: float64

# %%
df.min()
# Out:
# cgpa            9.00
# resume_score    4.95
# placed          0.00
# dtype: float64

# %%
r=df['cgpa'].mean()
r
# Out:
# np.float64(10.47)

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
s=df['cgpa'].median()
s
# Out:
# np.float64(10.0)

# %%
df.mean()#average
# Out:
# cgpa            10.4700
# resume_score     6.9305
# placed           0.5000
# dtype: float64

# %%
a=df.filter(items=['cgpa'])#filter out specific column
a
# Out:
#     cgpa
# 0     12
# 1     10
# 2     12
# 3     10
# 4     11
# ..   ...
# 95    10
# 96    12
# 97    10
# 98    12
# 99    10
#
# [100 rows x 1 columns]

# %%
df[['cgpa']]#second way to find specific column
# Out:
#     cgpa
# 0     12
# 1     10
# 2     12
# 3     10
# 4     11
# ..   ...
# 95    10
# 96    12
# 97    10
# 98    12
# 99    10
#
# [100 rows x 1 columns]

# %%
s=df.filter(items=[4,5,6],axis=0)#row wise axis=0
s
# Out:
#    cgpa  resume_score  placed
# 4    11          7.30       1
# 5    12          6.19       1
# 6     9          7.09       0

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
df.sort_index()#sorting elemnt by index
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
df.values
# Out:
# array([[12.  ,  6.52,  1.  ],
#        [10.  ,  5.17,  0.  ],
#        [12.  ,  8.86,  1.  ],
#        [10.  ,  7.27,  1.  ],
#        [11.  ,  7.3 ,  1.  ],
#        [12.  ,  6.19,  1.  ],
#        [ 9.  ,  7.09,  0.  ],
#        [10.  ,  6.29,  0.  ],
#        [10.  ,  6.71,  0.  ],
#        [11.  ,  7.12,  1.  ],
#        [10.  ,  6.35,  0.  ],
#        [ 9.  ,  6.54,  0.  ],
#        [10.  ,  7.01,  0.  ],
#        [12.  ,  5.09,  1.  ],
#        [11.  ,  6.25,  1.  ],
#        [12.  ,  5.93,  1.  ],
#        [12.  ,  7.64,  1.  ],
#        [11.  ,  8.71,  1.  ],
#        [ 9.  ,  5.88,  0.  ],
#        [10.  ,  8.11,  1.  ],
#        [ 9.  ,  8.06,  0.  ],
#        [10.  ,  7.64,  0.  ],
#        [10.  ,  5.77,  0.  ],
#        [10.  ,  7.13,  0.  ],
#        [12.  ,  6.18,  1.  ],
#        [11.  ,  5.68,  1.  ],
#        [10.  ,  6.47,  0.  ],
#        [ 9.  ,  6.15,  0.  ],
#        [11.  ,  7.67,  1.  ],
#        [10.  ,  7.3 ,  0.  ],
#        [11.  ,  7.15,  1.  ],
# ...

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
df.sum()
# Out:
# cgpa            1047.00
# resume_score     693.05
# placed            50.00
# dtype: float64

# %%
df.min()
# Out:
# cgpa            9.00
# resume_score    4.95
# placed          0.00
# dtype: float64

# %%
df.max()
# Out:
# cgpa            13.00
# resume_score     9.06
# placed           1.00
# dtype: float64

# %%
df.count()
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
new_df=pd.DataFrame(df.values,columns=df.columns)
new_df
# Out:
#     cgpa  resume_score  placed
# 0   12.0          6.52     1.0
# 1   10.0          5.17     0.0
# 2   12.0          8.86     1.0
# 3   10.0          7.27     1.0
# 4   11.0          7.30     1.0
# ..   ...           ...     ...
# 95  10.0          6.38     0.0
# 96  12.0          7.76     1.0
# 97  10.0          7.78     0.0
# 98  12.0          5.63     1.0
# 99  10.0          6.61     0.0
#
# [100 rows x 3 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
p=df.columns.tolist()
p
# Out:
# ['cgpa', 'resume_score', 'placed']

# %%
df.columns
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
df.columns.values
# Out:
# array(['cgpa', 'resume_score', 'placed'], dtype=object)

# %%
p=df.rename(columns={'cgpa':'updated_cgpa','resume_score':'sem_marks'})#rename column name
p
# Out:
#     updated_cgpa  sem_marks  placed
# 0             12       6.52       1
# 1             10       5.17       0
# 2             12       8.86       1
# 3             10       7.27       1
# 4             11       7.30       1
# ..           ...        ...     ...
# 95            10       6.38       0
# 96            12       7.76       1
# 97            10       7.78       0
# 98            12       5.63       1
# 99            10       6.61       0
#
# [100 rows x 3 columns]

# %%
df.dropna()
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
c=df.drop('placed',axis=1)#remove specific column

# %%
c
# Out:
#     cgpa  resume_score
# 0     12          6.52
# 1     10          5.17
# 2     12          8.86
# 3     10          7.27
# 4     11          7.30
# ..   ...           ...
# 95    10          6.38
# 96    12          7.76
# 97    10          7.78
# 98    12          5.63
# 99    10          6.61
#
# [100 rows x 2 columns]

# %%
df['nupur']=df['cgpa']+4#add column

# %%
df
# Out:
#     cgpa  resume_score  placed  nupur
# 0     12          6.52       1     16
# 1     10          5.17       0     14
# 2     12          8.86       1     16
# 3     10          7.27       1     14
# 4     11          7.30       1     15
# ..   ...           ...     ...    ...
# 95    10          6.38       0     14
# 96    12          7.76       1     16
# 97    10          7.78       0     14
# 98    12          5.63       1     16
# 99    10          6.61       0     14
#
# [100 rows x 4 columns]
